# %%
import os
import sys
import random
import shutil
import re
import time
import numpy as np
import glob
import tqdm
import cv2
import pandas as pd
import pickle
import json
from timeit import default_timer as timer
from operator import itemgetter

#plot
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches
ROOT_DIR = os.path.abspath("../../")

# %%
#function that quickly compute IoU and fct that says if a mask is included in another mask
#finally fct that remove useless masks on an image (either if IoU>0.7 or if one included in another:remove the smallest one)
#Note that we will compare bbox and not mask, as it will be faster and enough accurate

# %%
PACKAGE_PARENT = '../'
SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser('__file__'))))
sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))

from utils import plot_bboxes, remove_embedded_bbox, remove_embedded_bbox_keepindexonly, BinaryMaskPostProcessing
# Out:
# c:\users\camil\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# you are on windows, so pycocotools can not be installed

# %% [markdown]
# ## Load images & masks

# %%
path2data = os.path.join(ROOT_DIR, 'UTILS', 'mask&image', 'data')

# %%
#available data
print('AVAILABLE IMAGES: \n\n', ',\n '.join([x.split('\\')[-1] for x in glob.glob(os.path.join(path2data,'*.jpg'))]))
# Out:
# AVAILABLE IMAGES:
#
#  disjoint_mask.jpg,
#  three_superimposed_mask.jpg,
#  two_superimposed_mask_onebigger.jpg,
#  two_superimposed_mask_samesize.jpg

# %%
#choose data to work on
img_id = 'two_superimposed_mask_samesize.jpg'

# %%
#load mask
r = pickle.load(open(os.path.join(path2data, img_id[:-4]+'_maskrcnnoutput.pkl'), 'rb'))
#load image
image = cv2.imread(os.path.join(path2data, img_id))

# %% [markdown]
# #### processing

# %%
#list of masks
#li_m = [li_bmasks[:,:,i] for i in range(len(li_bmasks[0][0]))]

# %%
#takes a list of bbox ([(x,y,w,h),...]) with the associated image and plot on the image
li_bmasks = r['masks'] #binary masks
print('There is %d masks'%len(li_bmasks[0][0]))
li_bboxes = [(b[1], b[0], b[3]-b[1], b[2]-b[0]) for b in r['rois']] #x,y,w,h while maskrcnn output x1,y1,x2,y2
plot_bboxes(li_bboxes, image)
# Out:
# There is 5 masks

# %% [markdown]
# ## Mask post processing

# %%
start = timer()
rr = BinaryMaskPostProcessing(r)
end = timer()
print(end - start) 
plot_bboxes([(b[1], b[0], b[3]-b[1], b[2]-b[0]) for b in rr['rois']], image)
# Out:
# 4.698360909214614

# %% [markdown]
# #much faster if no need to remove a mask
# start = timer()
# BinaryMaskPostProcessing(rr)
# end = timer()
# print(end - start)

# %%
#https://www.kaggle.com/cpmpml/fast-iou-metric-in-numpy-and-tensorflow and then modified
#not yet verified nor used
def iou_metric_batch2(m1, m2):
    s1 = sum(sum(m1))
    s2 = sum(sum(m2))
    unions = np.sum(m1|m2)
    intersections = np.sum(m1*m2)
    print(s1,s2,unions,intersections)
    ious=np.maximum(0.0,np.ceil(20*intersections/np.where(unions==0.0,1,unions)-10)/10)
    return np.mean(np.where(unions==0,1,ious))
